# %% [markdown]
# <a href="https://colab.research.google.com/github/hjae0520/class2022Spring/blob/main/ViTForImageClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification
from PIL import Image
import requests

url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)

feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')

inputs = feature_extractor(images=image, return_tensors="pt")
outputs = model(**inputs)
logits = outputs.logits
# model predicts one of the 1000 ImageNet classes
predicted_class_idx = logits.argmax(-1).item()
# Out:
# Downloading:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/68.0k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/330M [00:00<?, ?B/s]
# Predicted class: Egyptian cat

# %%
print("Predicted class:", model.config.id2label[predicted_class_idx])   # image classification: 그림을 입력으로 받아 분류, 대부분의 classification 모델은 그 안에 한정된 class들이 다 있음
                                                                        # Egyptian cat도 class 중 하나로 ViTForImageClassification 모델 안에 저장되어 있는 것
# Out:
# Predicted class: Egyptian cat
